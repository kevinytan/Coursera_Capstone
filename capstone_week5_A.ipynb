# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods (Week 2)

# %% [markdown]
# ## Goals:
#
# 1. Introduction where you discuss the business problem and who would be interested in this project.
# 2. Data where you describe the data that will be used to solve the problem and the source of the data.
# 3. Methodology section which represents the main component of the report where you discuss and describe any exploratory data analysis that you did, any inferential statistical testing that you performed, if any, and what machine learnings were used and why.
# 4. Results section where you discuss the results.
# 5. Discussion section where you discuss any observations you noted and any recommendations you can make based on the results.
# 6. Conclusion section where you conclude the report.

# %% [markdown]
# ---

# %% [markdown]
# ## Intro
#
# I'd like to open a restaurant in Texas, specifically a Vietnamese one.  My candidate cities are Dallas, Austin, and Houston.  I'd like to open in an area of town that already has a considerable Asian/Vietnamese restaurant presence.  Walkability and the likability of nearby businesses is important.
#
# First, I'll narrow down which city to build in.  Then, select a more specific neighborhood within that city.  This is important for anyone who has the flexibility to open in any nearby city and may eventually want to franchise.

# %% [markdown]
# ---

# %% [markdown]
# ## Data
#
# #### Examples
#
# - FS API Search: https://developer.foursquare.com/docs/api-reference/venues/search/
# - FS API Likes: https://developer.foursquare.com/docs/api-reference/venues/likes/
# - Cities DB: https://simplemaps.com/data/us-cities
#
# #### Proposed Steps
#
# - Collect location data for the main cities I selected from Google/Wiki.
# - List neighborhood candidates for querying (pulled from external data).
# - Search for Asian/Viet restaurants in each city using Foursquare's API
# - Visualize on map
# - Identify candidate neighborhood/areas where Asian/Viet restaurants are frequent
# - Narrow down restaurants per city and re-visualize on map
# - Add category data from Foursquare's API
# - Add likes data from Foursquare's API
# - Group by neighborhoods and run a k-means clutering alg. to score the neighborhoods
# - Select where to build the restaurant

# %% [markdown]
# ---

# %% [markdown]
# ## Methodology

# %%
import pandas as pd
import requests
import bs4

# %%
# Gather coordinates of candidate cities

filename = 'uscities.csv'
csv_df = pd.read_csv(filename)

Cities = ['Dallas', 'Houston', 'Austin']
State = 'TX'

df = csv_df.loc[(csv_df['city'].isin(Cities)) & (csv_df['state_id'] == State)]
cities_df = df[['city','state_id','lat', 'lng']]
cities_df = cities_df.rename(columns={'city':'City','state_id':'State','lat':'Latitude', 'lng':'Longitude'})
cities_df
# Out:
#        City State  Latitude  Longitude
# 4    Dallas    TX   32.7936   -96.7662
# 6   Houston    TX   29.7863   -95.3889
# 31   Austin    TX   30.3004   -97.7522

# %%
# Map cities

import folium

# Texas coordinates
tx_coord = [31.7532, -96.3832]

# create map of Toronto using latitude and longitude values
map_tx = folium.Map(location=tx_coord, zoom_start=7)

# add markers to map
for lat, lng, city in zip(cities_df['Latitude'], cities_df['Longitude'], cities_df['City']):
    label = '{}'.format(city)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_tx)  
    
map_tx
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Foursquare API

CLIENT_ID = 'ZBY35LYFENJHYRKLT041HRBCRRUEIT1DGBSJJ1ULBK3EEVJA' # your Foursquare ID
CLIENT_SECRET = '02F30RSEVP1ULNOSAMNK2EOPIYUG41ZZTZI0WXLKY21YCM2G' # your Foursquare Secret
VERSION = '20201112'
LIMIT = 30
print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: ZBY35LYFENJHYRKLT041HRBCRRUEIT1DGBSJJ1ULBK3EEVJA
# CLIENT_SECRET:02F30RSEVP1ULNOSAMNK2EOPIYUG41ZZTZI0WXLKY21YCM2G

# %%
# Find coordinates of each city

dfw_coord = cities_df.loc[cities_df['City'] == 'Dallas'][['Latitude', 'Longitude']]
dfw_lat, dfw_lng = dfw_coord.Latitude.values[0], dfw_coord.Longitude.values[0]

htx_coord = cities_df.loc[cities_df['City'] == 'Houston'][['Latitude', 'Longitude']]
htx_lat, htx_lng = htx_coord.Latitude.values[0], htx_coord.Longitude.values[0]

atx_coord = cities_df.loc[cities_df['City'] == 'Austin'][['Latitude', 'Longitude']]
atx_lat, atx_lng = atx_coord.Latitude.values[0], atx_coord.Longitude.values[0]

print(f'Dallas coordinates are: {dfw_lat, dfw_lng}')
print(f'Houston coordinates are: {htx_lat, htx_lng}')
print(f'Austin coordinates are: {atx_lat, atx_lng}')
# Out:
# Dallas coordinates are: (32.7936, -96.7662)
# Houston coordinates are: (29.7863, -95.3889)
# Austin coordinates are: (30.3004, -97.7522)

# %%
# Create Foursquare /search API request

base_url = f'https://api.foursquare.com/v2/venues/search?&client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&v={VERSION}'

LIMIT = 100
Cities = ['Dallas', 'Houston', 'Austin']
State = 'TX'
query_term = "Vietnamese"

dfw_url = f'{base_url}&ll={dfw_lat},{dfw_lng}&limit={LIMIT}&near={Cities[0]}, {State}&query={query_term}'
htx_url = f'{base_url}&ll={htx_lat},{htx_lng}&limit={LIMIT}&near={Cities[1]}, {State}&query={query_term}'
atx_url = f'{base_url}&ll={atx_lat},{atx_lng}&limit={LIMIT}&near={Cities[2]}, {State}&query={query_term}'

dfw_url
# Out:
# 'https://api.foursquare.com/v2/venues/search?&client_id=ZBY35LYFENJHYRKLT041HRBCRRUEIT1DGBSJJ1ULBK3EEVJA&client_secret=02F30RSEVP1ULNOSAMNK2EOPIYUG41ZZTZI0WXLKY21YCM2G&v=20201112&ll=32.7936,-96.7662&limit=100&near=Dallas, TX&query=Vietnamese'

# %%
dfw_results = requests.get(dfw_url).json()
htx_results = requests.get(htx_url).json()
atx_results = requests.get(atx_url).json()

atx_results['response']
# Out:
# {'venues': [{'id': '4a9ebac6f964a520f63a20e3',
#    'name': '888 Vietnamese Restaurant',
#    'location': {'address': '2400 E Oltorf St',
#     'lat': 30.22962680466954,
#     'lng': -97.73011688665741,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 30.22962680466954,
#       'lng': -97.73011688665741},
#      {'label': 'entrance', 'lat': 30.229431, 'lng': -97.72963}],
#     'distance': 8159,
#     'postalCode': '78741',
#     'cc': 'US',
#     'city': 'Austin',
#     'state': 'TX',
#     'country': 'United States',
#     'formattedAddress': ['2400 E Oltorf St',
#      'Austin, TX 78741',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d14a941735',
#      'name': 'Vietnamese Restaurant',
#      'pluralName': 'Vietnamese Restaurants',
#      'shortName': 'Vietnamese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605648394',
#    'hasPerk': False},
#   {'id': '4e9cdd740aaf015a05c3dc1b',
#    'name': 'Duy Vietnamese Restaurant',
#    'location': {'address': '10901 N Lamar Blvd Ste A101',
#     'lat': 30.378247306157416,
#     'lng': -97.68767230631639,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 30.378247306157416,
#       'lng': -97.68767230631639}],
#     'distance': 10655,
#     'postalCode': '78753',
#     'cc': 'US',
#     'city': 'Austin',
#     'state': 'TX',
#     'country': 'United States',
#     'formattedAddress': ['10901 N Lamar Blvd Ste A101',
#      'Austin, TX 78753',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d14a941735',
#      'name': 'Vietnamese Restaurant',
#      'pluralName': 'Vietnamese Restaurants',
#      'shortName': 'Vietnamese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '1562094',
#     'url': 'https://www.grubhub.com/restaurant/duy-vietnamese-restaurant-10901-north-lamar-boulevard-austin/1562094?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1562094',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'referralId': 'v-1605648394',
#    'hasPerk': False},
#   {'id': '56f02681498eab944dae8438',
#    'name': 'T&L Vietnamese Cuisine',
#    'location': {'lat': 30.253432,
#     'lng': -97.713051,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 30.253432,
#       'lng': -97.713051}],
#     'distance': 6442,
#     'cc': 'US',
#     'city': 'Austin',
#     'state': 'TX',
#     'country': 'United States',
#     'formattedAddress': ['Austin, TX', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d14a941735',
#      'name': 'Vietnamese Restaurant',
#      'pluralName': 'Vietnamese Restaurants',
#      'shortName': 'Vietnamese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605648394',
#    'hasPerk': False},
#   {'id': '5d60379ce4337c00085857ba',
#    'name': 'Pho Dinh Vietnamese Cuisine',
#    'location': {'address': '9515 N Lamar Blvd',
#     'lat': 30.364037,
#     'lng': -97.694928,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 30.364037,
#       'lng': -97.694928}],
#     'distance': 8970,
#     'postalCode': '78753',
#     'cc': 'US',
#     'city': 'Austin',
#     'state': 'TX',
#     'country': 'United States',
#     'formattedAddress': ['9515 N Lamar Blvd',
#      'Austin, TX 78753',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d14a941735',
#      'name': 'Vietnamese Restaurant',
#      'pluralName': 'Vietnamese Restaurants',
#      'shortName': 'Vietnamese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '1270319',
#     'url': 'https://www.grubhub.com/restaurant/pho-dinh-vietnamese-cuisine-9515-n-lamar-blvd-ste-156-austin/1270319?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1270319',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'referralId': 'v-1605648394',
#    'hasPerk': False},
#   {'id': '4e95f5244901d620b77d4385',
#    'name': 'PhoNatic Vietnamese Cuisine',
#    'location': {'address': '2525 W Anderson Ln Bldg 3 Ste 208',
#     'lat': 30.355696910779148,
#     'lng': -97.7338148666229,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 30.355696910779148,
#       'lng': -97.7338148666229}],
#     'distance': 6404,
#     'postalCode': '78757',
#     'cc': 'US',
#     'city': 'Austin',
#     'state': 'TX',
#     'country': 'United States',
#     'formattedAddress': ['2525 W Anderson Ln Bldg 3 Ste 208',
#      'Austin, TX 78757',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d14a941735',
#      'name': 'Vietnamese Restaurant',
#      'pluralName': 'Vietnamese Restaurants',
#      'shortName': 'Vietnamese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605648394',
#    'hasPerk': False},
#   {'id': '54f0b178498e6bc708a18654',
#    'name': 'Hai ku Vietnamese Bistro',
#    'location': {'lat': 30.280946731567383,
#     'lng': -97.80715942382812,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 30.280946731567383,
#       'lng': -97.80715942382812}],
#     'distance': 5709,
#     'cc': 'US',
#     'city': 'West Lake Hills',
#     'state': 'TX',
#     'country': 'United States',
#     'formattedAddress': ['West Lake Hills, TX', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d14a941735',
#      'name': 'Vietnamese Restaurant',
#      'pluralName': 'Vietnamese Restaurants',
#      'shortName': 'Vietnamese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605648394',
#    'hasPerk': False},
#   {'id': '4b521e77f964a5206a6927e3',
#    'name': 'Pho Thaison Vietnamese Restaurant',
#    'location': {'address': '161 W Slaughter Ln',
#     'lat': 30.165848665034236,
#     'lng': -97.79238604938917,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 30.165848665034236,
#       'lng': -97.79238604938917},
#      {'label': 'entrance', 'lat': 30.166873, 'lng': -97.79195}],
#     'distance': 15468,
#     'postalCode': '78748',
#     'cc': 'US',
#     'city': 'Austin',
#     'state': 'TX',
#     'country': 'United States',
#     'formattedAddress': ['161 W Slaughter Ln',
#      'Austin, TX 78748',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d14a941735',
#      'name': 'Vietnamese Restaurant',
#      'pluralName': 'Vietnamese Restaurants',
#      'shortName': 'Vietnamese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '2245098',
#     'url': 'https://www.grubhub.com/restaurant/pho-thai-son-161-west-slaughter-lane-austin/2245098?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2245098',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'referralId': 'v-1605648394',
#    'hasPerk': False},
#   {'id': '4acf6ea9f964a5209fd320e3',
#    'name': 'Asia Chinese Restaurant',
#    'location': {'address': '1931 E Ben White Blvd',
#     'crossStreet': 'Woodward',
#     'lat': 30.215357223172287,
#     'lng': -97.74475423503813,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 30.215357223172287,
#       'lng': -97.74475423503813}],
#     'distance': 9493,
#     'postalCode': '78741',
#     'cc': 'US',
#     'city': 'Austin',
#     'state': 'TX',
#     'country': 'United States',
#     'formattedAddress': ['1931 E Ben White Blvd (Woodward)',
#      'Austin, TX 78741',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d145941735',
#      'name': 'Chinese Restaurant',
#      'pluralName': 'Chinese Restaurants',
#      'shortName': 'Chinese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '2328504',
#     'url': 'https://www.grubhub.com/restaurant/asia-chinese--vietnamese-1931-e-ben-white-blvd-austin/2328504?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2328504',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'referralId': 'v-1605648394',
#    'hasPerk': False},
#   {'id': '4b8318f8f964a52081f730e3',
#    'name': 'Hao Hao Vietnamese & Chinese Cuisine',
#    'location': {'address': '1205 Round Rock Ave',
#     'lat': 30.510722118228493,
#     'lng': -97.69462718988039,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 30.510722118228493,
#       'lng': -97.69462718988039},
#      {'label': 'entrance', 'lat': 30.511435, 'lng': -97.694127}],
#     'distance': 24056,
#     'postalCode': '78681',
#     'cc': 'US',
#     'city': 'Round Rock',
#     'state': 'TX',
#     'country': 'United States',
#     'formattedAddress': ['1205 Round Rock Ave',
#      'Round Rock, TX 78681',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d14a941735',
#      'name': 'Vietnamese Restaurant',
#      'pluralName': 'Vietnamese Restaurants',
#      'shortName': 'Vietnamese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '397804',
#     'url': 'https://www.grubhub.com/restaurant/hao-hao-vietnamese-chinese-restaurant-1205-round-rock-ave-ste-135-round-rock/397804?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=397804',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'venuePage': {'id': '90669970'},
#    'referralId': 'v-1605648394',
#    'hasPerk': False},
#   {'id': '5676e8a2498e2f30abd07c98',
#    'name': 'Austin Vietnamese Alliance Church',
#    'location': {'address': '1501 Kramer Ln',
#     'lat': 30.383682,
#     'lng': -97.70079100000001,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 30.383682,
#       'lng': -97.70079100000001},
#      {'label': 'entrance', 'lat': 30.383723, 'lng': -97.700749}],
#     'distance': 10504,
#     'postalCode': '78758',
#     'cc': 'US',
#     'city': 'Austin',
#     'state': 'TX',
#     'country': 'United States',
#     'formattedAddress': ['1501 Kramer Ln',
#      'Austin, TX 78758',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d132941735',
#      'name': 'Church',
#      'pluralName': 'Churches',
#      'shortName': 'Church',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605648394',
#    'hasPerk': False},
#   {'id': '4b41372bf964a52071c325e3',
#    'name': 'Hoa My Vietnamese Restaurant',
#    'location': {'address': '13000 N Interstate 35 #102',
#     'crossStreet': 'Parmer Ln',
#     'lat': 30.41090021015966,
#     'lng': -97.67611822795867,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 30.41090021015966,
#       'lng': -97.67611822795867}],
#     'distance': 14307,
#     'postalCode': '78753',
#     'cc': 'US',
#     'city': 'Austin',
#     'state': 'TX',
#     'country': 'United States',
#     'formattedAddress': ['13000 N Interstate 35 #102 (Parmer Ln)',
#      'Austin, TX 78753',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d14a941735',
#      'name': 'Vietnamese Restaurant',
#      'pluralName': 'Vietnamese Restaurants',
#      'shortName': 'Vietnamese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605648394',
#    'hasPerk': False},
#   {'id': '4a29c24af964a520d3951fe3',
#    'name': 'Sunflower Restaurant',
#    'location': {'address': '8557 Research Blvd, #146',
#     'lat': 30.361853463681648,
#     'lng': -97.7154676511655,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 30.361853463681648,
#       'lng': -97.7154676511655},
#      {'label': 'entrance', 'lat': 30.361048, 'lng': -97.716334}],
#     'distance': 7697,
#     'postalCode': '78758',
#     'cc': 'US',
#     'city': 'Austin',
#     'state': 'TX',
#     'country': 'United States',
#     'formattedAddress': ['8557 Research Blvd, #146',
#      'Austin, TX 78758',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d14a941735',
#      'name': 'Vietnamese Restaurant',
#      'pluralName': 'Vietnamese Restaurants',
#      'shortName': 'Vietnamese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605648394',
#    'hasPerk': False},
#   {'id': '4f086eede4b0e8907a8a8a4a',
#    'name': 'Holy Vietnamese Martyrs Catholic Church',
#    'location': {'lat': 30.389846999999996,
#     'lng': -97.658682,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 30.389846999999996,
#       'lng': -97.658682},
#      {'label': 'entrance', 'lat': 30.390127, 'lng': -97.658192}],
#     'distance': 13411,
#     'postalCode': '78701',
#     'cc': 'US',
#     'city': 'Austin',
#     'state': 'TX',
#     'country': 'United States',
#     'formattedAddress': ['Austin, TX 78701', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d132941735',
#      'name': 'Church',
#      'pluralName': 'Churches',
#      'shortName': 'Church',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605648394',
#    'hasPerk': False},
#   {'id': '4a5cbc97f964a5207bbc1fe3',
#    'name': 'Pho Saigon',
#    'location': {'address': '10901 N Lamar Blvd #108',
#     'crossStreet': 'Chinatown Center',
#     'lat': 30.378036303841842,
#     'lng': -97.68720454742908,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 30.378036303841842,
#       'lng': -97.68720454742908},
#      {'label': 'entrance', 'lat': 30.377831, 'lng': -97.68611}],
#     'distance': 10662,
#     'postalCode': '78753',
#     'cc': 'US',
#     'city': 'Austin',
#     'state': 'TX',
#     'country': 'United States',
#     'formattedAddress': ['10901 N Lamar Blvd #108 (Chinatown Center)',
#      'Austin, TX 78753',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d14a941735',
#      'name': 'Vietnamese Restaurant',
#      'pluralName': 'Vietnamese Restaurants',
#      'shortName': 'Vietnamese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '1581329',
#     'url': 'https://www.grubhub.com/restaurant/pho-saigon-noodle-house-10901-north-lamar-boulevard-austin/1581329?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1581329',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'referralId': 'v-1605648394',
#    'hasPerk': False},
#   {'id': '5b20009989e490002c85669d',
#    'name': 'Moi Vietnamese Grill',
#    'location': {'address': '16051 Dessau Rd Ste A',
#     'lat': 30.434334,
#     'lng': -97.61537,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 30.434334,
#       'lng': -97.61537}],
#     'distance': 19874,
#     'postalCode': '78660',
#     'cc': 'US',
#     'city': 'Pflugerville',
#     'state': 'TX',
#     'country': 'United States',
#     'formattedAddress': ['16051 Dessau Rd Ste A',
#      'Pflugerville, TX 78660',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d14a941735',
#      'name': 'Vietnamese Restaurant',
#      'pluralName': 'Vietnamese Restaurants',
#      'shortName': 'Vietnamese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '1477268',
#     'url': 'https://www.grubhub.com/restaurant/moi-vietnamese-grill-16051-dessau-rd-ste-c-pflugerville/1477268?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1477268',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'referralId': 'v-1605648394',
#    'hasPerk': False},
#   {'id': '52e851b5498e38c84c1deb2c',
#    'name': 'PhoNatic Vietnamese Cuisine',
#    'location': {'address': '1468 E Whitestone Blvd #200',
#     'lat': 30.526676557091626,
#     'lng': -97.80899140676526,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 30.526676557091626,
#       'lng': -97.80899140676526}],
#     'distance': 25772,
#     'postalCode': '78613',
#     'cc': 'US',
#     'city': 'Cedar Park',
#     'state': 'TX',
#     'country': 'United States',
#     'formattedAddress': ['1468 E Whitestone Blvd #200',
#      'Cedar Park, TX 78613',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d14a941735',
#      'name': 'Vietnamese Restaurant',
#      'pluralName': 'Vietnamese Restaurants',
#      'shortName': 'Vietnamese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1605648394',
#    'hasPerk': False}],
#  'geocode': {'what': '',
#   'where': 'austin tx',
#   'feature': {'cc': 'US',
#    'name': 'Austin',
#    'displayName': 'Austin, TX',
#    'matchedName': 'Austin, TX',
#    'highlightedName': '<b>Austin</b>, <b>TX</b>',
#    'woeType': 7,
#    'slug': 'austin-texas',
#    'id': 'geonameid:4671654',
#    'longId': '72057594042599590',
#    'geometry': {'center': {'lat': 30.26715, 'lng': -97.74306},
#     'bounds': {'ne': {'lat': 30.516862999999997, 'lng': -97.561489},
#      'sw': {'lat': 30.098658999999998, 'lng': -97.938383}}}},
#   'parents': []}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
# Load JSON response into DF and clean

filtered_cols = ['name', 'location.lat', 'location.lng', 'categories', 'id']

atx_venues_df = json_normalize(atx_results['response']['venues'])
atx_venues_df = atx_venues_df.loc[:, filtered_cols]
atx_venues_df['categories'] = atx_venues_df.apply(get_category_type, axis=1)
atx_venues_df = atx_venues_df.rename(columns={'name':'Name','location.lat':'Latitude','location.lng':'Longitude', 'categories':'Categories'})

atx_venues_df
# Out:
#                                        Name   Latitude  Longitude  \
# 0                 888 Vietnamese Restaurant  30.229627 -97.730117
# 1                 Duy Vietnamese Restaurant  30.378247 -97.687672
# 2                    T&L Vietnamese Cuisine  30.253432 -97.713051
# 3               Pho Dinh Vietnamese Cuisine  30.364037 -97.694928
# 4               PhoNatic Vietnamese Cuisine  30.355697 -97.733815
# 5                  Hai ku Vietnamese Bistro  30.280947 -97.807159
# 6         Pho Thaison Vietnamese Restaurant  30.165849 -97.792386
# 7                   Asia Chinese Restaurant  30.215357 -97.744754
# 8      Hao Hao Vietnamese & Chinese Cuisine  30.510722 -97.694627
# 9         Austin Vietnamese Alliance Church  30.383682 -97.700791
# 10             Hoa My Vietnamese Restaurant  30.410900 -97.676118
# 11                     Sunflower Restaurant  30.361853 -97.715468
# 12  Holy Vietnamese Martyrs Catholic Church  30.389847 -97.658682
# 13                               Pho Saigon  30.378036 -97.687205
# 14                     Moi Vietnamese Grill  30.434334 -97.615370
# 15              PhoNatic Vietnamese Cuisine  30.526677 -97.808991
#
#                Categories                        id
# 0   Vietnamese Restaurant  4a9ebac6f964a520f63a20e3
# 1   Vietnamese Restaurant  4e9cdd740aaf015a05c3dc1b
# 2   Vietnamese Restaurant  56f02681498eab944dae8438
# 3   Vietnamese Restaurant  5d60379ce4337c00085857ba
# 4   Vietnamese Restaurant  4e95f5244901d620b77d4385
# 5   Vietnamese Restaurant  54f0b178498e6bc708a18654
# 6   Vietnamese Restaurant  4b521e77f964a5206a6927e3
# 7      Chinese Restaurant  4acf6ea9f964a5209fd320e3
# 8   Vietnamese Restaurant  4b8318f8f964a52081f730e3
# 9                  Church  5676e8a2498e2f30abd07c98
# 10  Vietnamese Restaurant  4b41372bf964a52071c325e3
# 11  Vietnamese Restaurant  4a29c24af964a520d3951fe3
# 12                 Church  4f086eede4b0e8907a8a8a4a
# 13  Vietnamese Restaurant  4a5cbc97f964a5207bbc1fe3
# 14  Vietnamese Restaurant  5b20009989e490002c85669d
# 15  Vietnamese Restaurant  52e851b5498e38c84c1deb2c

# %%
print('{} venues were returned by Foursquare for Austin.'.format(atx_venues_df.shape[0]))
# Out:
# 16 venues were returned by Foursquare for Austin.

# %%
# Add empty column placeholder for 'Likes' count
atx_venues_df['Likes'] = ""
atx_venues_df.head()
# Out:
#                           Name   Latitude  Longitude             Categories  \
# 0    888 Vietnamese Restaurant  30.229627 -97.730117  Vietnamese Restaurant
# 1    Duy Vietnamese Restaurant  30.378247 -97.687672  Vietnamese Restaurant
# 2       T&L Vietnamese Cuisine  30.253432 -97.713051  Vietnamese Restaurant
# 3  Pho Dinh Vietnamese Cuisine  30.364037 -97.694928  Vietnamese Restaurant
# 4  PhoNatic Vietnamese Cuisine  30.355697 -97.733815  Vietnamese Restaurant
#
#                          id Likes
# 0  4a9ebac6f964a520f63a20e3
# 1  4e9cdd740aaf015a05c3dc1b
# 2  56f02681498eab944dae8438
# 3  5d60379ce4337c00085857ba
# 4  4e95f5244901d620b77d4385

# %%
# Collect likes for businesses and add back into dataframe as new column

for index, row in atx_venues_df.iterrows():
    id = row['id']
    url = f'https://api.foursquare.com/v2/venues/{id}/likes?&client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}&v={VERSION}'
    results = requests.get(url).json()
    atx_venues_df.loc[index, 'Likes'] = results['response']['likes']['count']

atx_venues_df
# Out:
#                                        Name   Latitude  Longitude  \
# 0                 888 Vietnamese Restaurant  30.229627 -97.730117
# 1                 Duy Vietnamese Restaurant  30.378247 -97.687672
# 2                    T&L Vietnamese Cuisine  30.253432 -97.713051
# 3               Pho Dinh Vietnamese Cuisine  30.364037 -97.694928
# 4               PhoNatic Vietnamese Cuisine  30.355697 -97.733815
# 5                  Hai ku Vietnamese Bistro  30.280947 -97.807159
# 6         Pho Thaison Vietnamese Restaurant  30.165849 -97.792386
# 7                   Asia Chinese Restaurant  30.215357 -97.744754
# 8      Hao Hao Vietnamese & Chinese Cuisine  30.510722 -97.694627
# 9         Austin Vietnamese Alliance Church  30.383682 -97.700791
# 10             Hoa My Vietnamese Restaurant  30.410900 -97.676118
# 11                     Sunflower Restaurant  30.361853 -97.715468
# 12  Holy Vietnamese Martyrs Catholic Church  30.389847 -97.658682
# 13                               Pho Saigon  30.378036 -97.687205
# 14                     Moi Vietnamese Grill  30.434334 -97.615370
# 15              PhoNatic Vietnamese Cuisine  30.526677 -97.808991
#
#                Categories                        id Likes
# 0   Vietnamese Restaurant  4a9ebac6f964a520f63a20e3   382
# 1   Vietnamese Restaurant  4e9cdd740aaf015a05c3dc1b    14
# 2   Vietnamese Restaurant  56f02681498eab944dae8438     0
# 3   Vietnamese Restaurant  5d60379ce4337c00085857ba     0
# 4   Vietnamese Restaurant  4e95f5244901d620b77d4385    64
# 5   Vietnamese Restaurant  54f0b178498e6bc708a18654     0
# 6   Vietnamese Restaurant  4b521e77f964a5206a6927e3    26
# 7      Chinese Restaurant  4acf6ea9f964a5209fd320e3     9
# 8   Vietnamese Restaurant  4b8318f8f964a52081f730e3    24
# 9                  Church  5676e8a2498e2f30abd07c98     0
# 10  Vietnamese Restaurant  4b41372bf964a52071c325e3     6
# 11  Vietnamese Restaurant  4a29c24af964a520d3951fe3    38
# 12                 Church  4f086eede4b0e8907a8a8a4a     2
# 13  Vietnamese Restaurant  4a5cbc97f964a5207bbc1fe3   171
# 14  Vietnamese Restaurant  5b20009989e490002c85669d     1
# 15  Vietnamese Restaurant  52e851b5498e38c84c1deb2c    19

# %%
# Clean DF for clustering
# Remove non numerical values
# Alternatively: One-Hot encode them

atx_clustering = atx_venues_df.drop(['Name', 'Categories', 'id'], 1)
atx_clustering
# Out:
#      Latitude  Longitude Likes
# 0   30.229627 -97.730117   382
# 1   30.378247 -97.687672    14
# 2   30.253432 -97.713051     0
# 3   30.364037 -97.694928     0
# 4   30.355697 -97.733815    64
# 5   30.280947 -97.807159     0
# 6   30.165849 -97.792386    26
# 7   30.215357 -97.744754     9
# 8   30.510722 -97.694627    24
# 9   30.383682 -97.700791     0
# 10  30.410900 -97.676118     6
# 11  30.361853 -97.715468    38
# 12  30.389847 -97.658682     2
# 13  30.378036 -97.687205   171
# 14  30.434334 -97.615370     1
# 15  30.526677 -97.808991    19

# %%
# import k-means from clustering stage
from sklearn.cluster import KMeans

# set number of clusters
kclusters = 3

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=1).fit(atx_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# array([1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2], dtype=int32)

# %%
# Add Cluster Label back into DF

atx_venues_df.insert(0, 'Cluster Label', kmeans.labels_)
atx_venues_df.head()
# Out:
#    Cluster Label                         Name   Latitude  Longitude  \
# 0              1    888 Vietnamese Restaurant  30.229627 -97.730117
# 1              2    Duy Vietnamese Restaurant  30.378247 -97.687672
# 2              2       T&L Vietnamese Cuisine  30.253432 -97.713051
# 3              2  Pho Dinh Vietnamese Cuisine  30.364037 -97.694928
# 4              2  PhoNatic Vietnamese Cuisine  30.355697 -97.733815
#
#               Categories                        id Likes
# 0  Vietnamese Restaurant  4a9ebac6f964a520f63a20e3   382
# 1  Vietnamese Restaurant  4e9cdd740aaf015a05c3dc1b    14
# 2  Vietnamese Restaurant  56f02681498eab944dae8438     0
# 3  Vietnamese Restaurant  5d60379ce4337c00085857ba     0
# 4  Vietnamese Restaurant  4e95f5244901d620b77d4385    64

# %%
# Map Austin businesses

# Matplotlib and associated plotting modules
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors as colors
import folium

# Texas coordinates
atx_coord = [atx_lat, atx_lng]

# create map of Austin using latitude and longitude values
map_atx = folium.Map(location=atx_coord, zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to map
for lat, lng, name, likes, cluster in zip(atx_venues_df['Latitude'], atx_venues_df['Longitude'], atx_venues_df['Name'], atx_venues_df['Likes'], atx_venues_df['Cluster Label']):
    label = '{}: {}'.format(name, likes)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7,
        parse_html=False).add_to(map_atx)  
    
map_atx
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # ---

# %% [markdown]
# ## Goals:
#
# 3. Methodology section which represents the main component of the report where you discuss and describe any exploratory data analysis that you did, any inferential statistical testing that you performed, if any, and what machine learnings were used and why.
# 4. Results section where you discuss the results.
# 5. Discussion section where you discuss any observations you noted and any recommendations you can make based on the results.
# 6. Conclusion section where you conclude the report.

# %% [markdown]
# ---

# %% [markdown]
# ## Results

# %% [markdown]
# ---

# %% [markdown]
# ## Discussion

# %% [markdown]
# ---

# %% [markdown]
# ## Conclusion
